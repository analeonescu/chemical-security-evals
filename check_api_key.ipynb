# %%
from google import genai
import os
print("GEMINI_API_KEY" in os.environ)
print("GOOGLE_API_KEY" in os.environ)
client = genai.Client(api_key=os.environ["GEMINI_API_KEY"])  # Replace with
for model in client.models.list():
    print(model.name)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# True
# True
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[1], line 6
#       4 print("GOOGLE_API_KEY" in os.environ)
#       5 client = genai.Client(api_key=os.environ["GEMINI_API_KEY"])  # Replace with
# ----> 6 for model in client.models.list():
#       7     print(model.name)
#
# File c:\Users\aleon\anaconda3\Lib\site-packages\google\genai\models.py:7129, in Models.list(self, config)
#    7120     filter_value = config.filter
#    7121     config.filter = (
#    7122         filter_value + '&filter=labels.tune-type:*'
#    7123         if filter_value
#    7124         else 'labels.tune-type:*'
#    7125     )
#    7126 return Pager(
#    7127     'models',
#    7128     self._list,
# -> 7129     self._list(config=config),
#    7130     config,
#    7131 )
#
# ...

# %%
import os

for key in os.environ:
    if "API" in key.upper() or "GEMINI" in key.upper() or "GOOGLE" in key.upper():
        print(key)
# Out:
# GEMINI_API_KEY
# GOOGLE_API_KEY
# MISTRAL_API_KEY
# OPENAI_API_KEY

# %%
print("GOOGLE_API_KEY =", os.environ.get("GOOGLE_API_KEY")[:10])
print("GEMINI_API_KEY =", os.environ.get("GEMINI_API_KEY")[:10])
# Out:
# GOOGLE_API_KEY = AQ.Ab8RN6I
# GEMINI_API_KEY = AIzaSyBAZM
